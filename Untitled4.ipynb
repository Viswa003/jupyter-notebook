# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
if __name__ == '__main__':
    n = 10000
    p = 0.6
    x = np.arange(binom.ppf(0.01, n, p), binom.ppf(0.99, n, p))
    plt.plot(x, binom.pmf(x, n, p), 'o', markersize=2, label='Binomial(10000, 0.6)')
    plt.legend()
    plt.show()
